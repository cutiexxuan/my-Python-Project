# %%
import os  # Import the os library
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: c:\Python

# %%
os.chdir("C:/Python")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from lets_plot import *
from scipy import stats
import statsmodels.api as sm 

# before using lets_plot you need to call the setup
LetsPlot.setup_html(no_js=True)

# %%
! pip install lets_plot
# Out:
# Requirement already satisfied: lets_plot in c:\anaconda\lib\site-packages (4.5.2)
# Requirement already satisfied: pypng in c:\anaconda\lib\site-packages (from lets_plot) (0.20220715.0)
# Requirement already satisfied: palettable in c:\anaconda\lib\site-packages (from lets_plot) (3.3.3)

# %%
fes_data = pd.read_stata("datafes.dta")
fes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189671 entries, 0 to 189670
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   year      189656 non-null  float64
#  1   age       189656 non-null  float64
#  2   coh       189671 non-null  category
#  3   famtype   189656 non-null  category
#  4   totexp    189656 non-null  float32
#  5   totexpeq  189656 non-null  float32
#  6   totnd     189656 non-null  float32
#  7   totndeq   189656 non-null  float32
#  8   income    187842 non-null  float32
# dtypes: category(2), float32(5), float64(2)
# memory usage: 6.9 MB

# %%
fes_data.head()
# Out:
#    year   age           coh                                   famtype  \
# 0  74.0  41.0  born 1930-39  10 Extended family plus children
# 1  74.0  61.0  born 1910-19  5  Couple
# 2  74.0  82.0    born 1900-  1  Single
# 3  74.0  41.0  born 1930-39  6  Couple plus dependent children
# 4  74.0  40.0  born 1930-39  2  Lone plus dependent children
#
#        totexp    totexpeq       totnd    totndeq      income
# 0  565.546204  137.938095  370.877502  90.457932  620.269775
# 1  173.752411  102.207298  121.898033  71.704727  316.160767
# 2   83.631500   83.631500   41.325153  41.325153   72.689499
# 3  300.285736  111.216934  194.519867  72.044395  342.416138
# 4  238.775070  119.387535  168.237427  84.118713  259.332764

# %%
fes_data['famtype'].value_counts()
# Out:
# famtype
# 5  Couple                                   50651
# 6  Couple plus dependent children           46666
# 1  Single                                   46040
# 7  Couple plus non dependent children       10653
# 2  Lone plus dependent children              8262
# 9  Extended family                           8139
# 8  Couple plus both                          7313
# 11 Other multiple tax unit                   3499
# 10 Extended family plus children             3368
# 3  Lone plus non dependent children          3063
# 4  Lone plus both                            1307
# 12 Other multiple tax unit plus children      695
# Name: count, dtype: int64

# %%
fes_data_couple = fes_data.query('famtype in ["5  Couple                               ","7  Couple plus non dependent children   "]').copy()

# %%
fes_data_couple['coh'].value_counts()
# Out:
# coh
# born 1920-29    15095
# born 1930-39    11107
# born 1910-19    10687
# born 1940-49     8269
# born 1950-59     5877
# born 1900-09     4623
# born 1960-69     3872
# born 1970+       1070
# born 1900-        704
# Name: count, dtype: int64

# %%
fes_data_sel = fes_data_couple.query('coh in ["born 1930-39","born 1940-49","born 1950-59"]').copy()
fes_data_sel['coh'].value_counts()
# Out:
# coh
# born 1930-39    11107
# born 1940-49     8269
# born 1950-59     5877
# born 1970+          0
# born 1960-69        0
# born 1920-29        0
# born 1910-19        0
# born 1900-09        0
# born 1900-          0
# Name: count, dtype: int64

# %%
fes_data_sel['income'].describe()
# Out:
# count    24943.000000
# mean       623.546997
# std        453.475769
# min          0.000000
# 25%        380.823547
# 50%        549.334656
# 75%        768.025391
# max      18904.652344
# Name: income, dtype: float64

# %%
p1 = ggplot(fes_data_sel, aes(x = 'income')) + geom_histogram(binwidth = 500)
p1
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #ps012JT .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #ps012JT .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #ps012JT .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #ps012JT .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #ps012JT .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #ps012JT .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #ps012JT .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #ps012JT .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dLaSr9X .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #ps012JT .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #ps012JT .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dLaSr9X .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #ps012JT .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #ps012JT .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dLaSr9X .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dLaSr9X .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dLaSr9X .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="ps012JT">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 6.5 ) ">
#       <g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="31.480986420816997" y1="0.0" x2="31.480986420816997" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="148.0772324238429" y1="0.0" x2="148.0772324238429" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="264.6734784268688" y1="0.0" x2="264.6734784268688" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="381.2697244298947" y1="0.0" x2="381.2697244298947" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="497.8659704329206" y1="0.0" x2="497.8659704329206" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="341.0" x2="513.023482413314" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="297.31985141063825" x2="513.023482413314" y2="297.31985141063825" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="253.63970282127644" x2="513.023482413314" y2="253.63970282127644" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="209.9595542319147" x2="513.023482413314" y2="209.9595542319147" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="166.27940564255292" x2="513.023482413314" y2="166.27940564255292" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="122.59925705319114" x2="513.023482413314" y2="122.59925705319114" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="78.91910846382939" x2="513.023482413314" y2="78.91910846382939" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="35.23895987446764" x2="513.023482413314" y2="35.23895987446764" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cMAFTRM)" clip-bounds-jfx="[rect (50.97651758668602, 0.0), (513.023482413314, 341.0)]">
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <g>
#               <rect x="478.0446086124062" y="341.0" height="0.1" width="11.659624600302607" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="466.38498401210364" y="340.9781599257053" height="0.02184007429468693" width="11.65962460030255" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="454.72535941180104" y="341.0" height="0.1" width="11.659624600302607" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="443.06573481149843" y="341.0" height="0.1" width="11.659624600302607" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="431.4061102111958" y="341.0" height="0.1" width="11.659624600302607" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="419.7464856108933" y="340.9781599257053" height="0.02184007429468693" width="11.65962460030255" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="408.08686101059067" y="341.0" height="0.1" width="11.659624600302607" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="396.42723641028806" y="341.0" height="0.1" width="11.659624600302607" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="384.7676118099855" y="341.0" height="0.1" width="11.65962460030255" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="373.1079872096829" y="340.9781599257053" heig

# %%
p2 = (ggplot(fes_data_sel, aes(x = 'income')) + 
      geom_histogram(binwidth = 100) + 
      xlim(0,5000) +
      labs(title = "Histogram, income, max 5000"))
p2
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pavDJat .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pavDJat .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pavDJat .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pavDJat .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pavDJat .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pavDJat .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pavDJat .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pavDJat .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dZ5EFbW .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pavDJat .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pavDJat .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dZ5EFbW .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pavDJat .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pavDJat .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dZ5EFbW .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dZ5EFbW .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dZ5EFbW .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pavDJat">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(42.99591213121782 0.0 ) ">
#           <g>
#             <line x1="23.682003994035554" y1="0.0" x2="23.682003994035554" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="117.8450417436799" y1="0.0" x2="117.8450417436799" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="212.00807949332426" y1="0.0" x2="212.00807949332426" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="306.1711172429686" y1="0.0" x2="306.1711172429686" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="400.3341549926129" y1="0.0" x2="400.3341549926129" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="494.4971927422573" y1="0.0" x2="494.4971927422573" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(42.99591213121782 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="321.0" x2="521.0040878687822" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="280.4650907300072" x2="521.0040878687822" y2="280.4650907300072" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="239.9301814600144" x2="521.0040878687822" y2="239.9301814600144" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="199.39527219002161" x2="521.0040878687822" y2="199.39527219002161" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="158.8603629200288" x2="521.0040878687822" y2="158.8603629200288" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="118.325453650036" x2="521.0040878687822" y2="118.325453650036" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="77.7905443800432" x2="521.0040878687822" y2="77.7905443800432" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="37.25563511005038" x2="521.0040878687822" y2="37.25563511005038" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#coyhqAx)" clip-bounds-jfx="[rect (42.99591213121782, 0.0), (521.0040878687822, 321.0)]">
#         <g transform="translate(42.99591213121782 0.0 ) ">
#           <g>
#             <g>
#               <rect x="487.9057800997822" y="320.91893018146004" height="0.08106981853995876" width="9.416303774964433" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="478.48947632481776" y="320.91893018146004" height="0.08106981853995876" width="9.416303774964433" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="469.0731725498533" y="320.91893018146004" height="0.08106981853995876" width="9.416303774964433" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="459.6568687748889" y="320.91893018146004" height="0.08106981853995876" width="9.416303774964433" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="450.24056499992446" y="320.91893018146004" height="0.08106981853995876" width="9.416303774964433" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="440.82426122496" y="320.91893018146004" height="0.08106981853995876" width="9.416303774964433" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="431.4079574499956" y="320.91893018146004" height="0.08106981853995876" width="9.416303774964433" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="421.99165367503116" y="320.83786036292" height="0.16213963707997436" width="9.416303774964433" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)

# %%
fes_data_sel = fes_data_sel.query('income > 0').copy()
fes_data_sel['lincome'] = np.log(fes_data_sel['income'])
fes_data_sel['lincome'].describe()
# Out:
# count    24937.000000
# mean         6.256570
# std          0.625843
# min         -3.159846
# 25%          5.942802
# 50%          6.308816
# 75%          6.643944
# max          9.847163
# Name: lincome, dtype: float64

# %%
p3 = (ggplot(fes_data_sel, aes(x = 'lincome')) + 
      geom_histogram(binwidth = 0.1) + 
      labs(title = "Histogram, ln(income)"))
p3
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pxWQHXY .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pxWQHXY .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pxWQHXY .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pxWQHXY .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pxWQHXY .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pxWQHXY .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pxWQHXY .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pxWQHXY .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dTMbLuM .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pxWQHXY .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pxWQHXY .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dTMbLuM .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pxWQHXY .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pxWQHXY .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dTMbLuM .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dTMbLuM .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dTMbLuM .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pxWQHXY">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(42.99591213121782 0.0 ) ">
#           <g>
#             <line x1="67.81112441963064" y1="0.0" x2="67.81112441963064" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="139.57477288640504" y1="0.0" x2="139.57477288640504" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="211.33842135317946" y1="0.0" x2="211.33842135317946" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="283.10206981995384" y1="0.0" x2="283.10206981995384" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="354.8657182867282" y1="0.0" x2="354.8657182867282" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="426.6293667535026" y1="0.0" x2="426.6293667535026" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="498.393015220277" y1="0.0" x2="498.393015220277" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(42.99591213121782 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="321.0" x2="521.0040878687822" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="245.8859248859249" x2="521.0040878687822" y2="245.8859248859249" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="170.7718497718498" x2="521.0040878687822" y2="170.7718497718498" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="95.65777465777467" x2="521.0040878687822" y2="95.65777465777467" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="20.543699543699574" x2="521.0040878687822" y2="20.543699543699574" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cxPiJx3)" clip-bounds-jfx="[rect (42.99591213121782, 0.0), (521.0040878687822, 321.0)]">
#         <g transform="translate(42.99591213121782 0.0 ) ">
#           <g>
#             <g>
#               <rect x="493.73390145140786" y="321.0" height="0.1" width="3.588182423338708" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="490.14571902806915" y="320.84977184977186" height="0.15022815022814484" width="3.588182423338708" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="486.55753660473044" y="320.84977184977186" height="0.15022815022814484" width="3.588182423338708" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="482.96935418139174" y="320.84977184977186" height="0.15022815022814484" width="3.588182423338708" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="479.38117175805303" y="321.0" height="0.1" width="3.588182423338708" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="475.7929893347143" y="320.84977184977186" height="0.15022815022814484" width="3.588182423338708" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="472.2048069113755" y="321.0" height="0.1" width="3.588182423338708" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="468.6166244880368" y="320.84977184977186" height="0.15022815022814484" width="3.588182423338708" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="465.0284420646981" y="320.54931554931557" height="0.4506844506844345" width="3.588182423338708" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="1.0" stroke-width="1.1">
#               </rect>
#               <rect x="461.4402596413594" y="321.0" height="0.1" width="3.588182423338708" stroke="rgb(71,71,71)" stroke-opacity="1.0" fill="rgb(71,71,71)" fill-opacity="

# %%
mu = np.mean(fes_data_sel['lincome'])  # mean estimate
sig2 = np.std((fes_data_sel['lincome']))**2 # variance estimate
print("sample mean = ", round(mu,2), ", Sample variance =", round(sig2,2))
# Out:
# sample mean =  6.26 , Sample variance = 0.39

# %%
lx_range = np.arange(-2,10,0.01)
lx_pdf = (1/(np.sqrt(2*np.pi*sig2)))*np.exp(-(lx_range-mu)**2/(2*sig2))
lx_pdf_plot = {'lincome': lx_range,
                'lx_pdf': lx_pdf}
lx_pdf_plot = pd.DataFrame(lx_pdf_plot)

# %%
p4 = (ggplot(lx_pdf_plot, aes(x = 'lincome', y = 'lx_pdf')) + 
      geom_line() + 
      labs(title = "ln(income), ML estimate N"))
p4
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pzho3YO .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pzho3YO .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pzho3YO .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pzho3YO .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pzho3YO .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pzho3YO .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pzho3YO .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pzho3YO .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dk6snFp .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pzho3YO .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pzho3YO .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dk6snFp .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pzho3YO .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pzho3YO .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dk6snFp .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dk6snFp .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dk6snFp .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pzho3YO">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <line x1="24.407513580896307" y1="0.0" x2="24.407513580896307" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="105.83374737871542" y1="0.0" x2="105.83374737871542" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="187.25998117653452" y1="0.0" x2="187.25998117653452" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="268.6862149743536" y1="0.0" x2="268.6862149743536" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="350.11244877217274" y1="0.0" x2="350.11244877217274" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="431.53868256999186" y1="0.0" x2="431.53868256999186" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="512.9649163678109" y1="0.0" x2="512.9649163678109" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="306.4090909090909" x2="536.9652987797186" y2="306.4090909090909" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="260.6301438744497" x2="536.9652987797186" y2="260.6301438744497" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="214.85119683980844" x2="536.9652987797186" y2="214.85119683980844" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="169.07224980516722" x2="536.9652987797186" y2="169.07224980516722" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="123.29330277052603" x2="536.9652987797186" y2="123.29330277052603" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="77.51435573588483" x2="536.9652987797186" y2="77.51435573588483" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="31.735408701243614" x2="536.9652987797186" y2="31.735408701243614" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#ckqZgzl)" clip-bounds-jfx="[rect (27.034701220281416, 0.0), (536.9652987797186, 321.0)]">
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M24.407513580896307 306.4090909090909 L24.407513580896307 306.4090909090909 L24.814644749885403 306.4090909090909 L25.2217759188745 306.4090909090909 L25.628907087863595 306.4090909090909 L26.03603825685269 306.4090909090909 L26.443169425841788 306.4090909090909 L26.850300594830884 306.4090909090909 L27.25743176381998 306.4090909090909 L27.664562932809076 306.4090909090909 L28.071694101798172 306.4090909090909 L28.47882527078727 306.4090909090909 L28.885956439776365 306.4090909090909 L29.29308760876546 306.4090909090909 L29.700218777754557 306.4090909090909 L30.107349946743653 306.4090909090909 L30.51448111573275 306.4090909090909 L30.921612284721846 306.4090909090909 L31.328743453710942 306.4090909090909 L31.735874622700038 306.4090909090909 L32.143005791689134 306.4090909090909 L32.55013696067823 306.4090909090909 L32.95726812966733 306.4090909090909 L33.36439929865642 306.4090909090909 L33.77153046764552 306.4090909090909 L34.178661636634615 306.4090909090909 L34.58579280562371 306.4090909090909 L34.99292397461279 306.4090909090909 L35.40005514360189 306.4090909090909 L35.807186312590986 306.4090909090909 L36.21431748158008 306.4090909090909 L36.62144865056918 306.4090909090909 L37.028579819558274 306.4090909090909 L37.43571098854737 306.4090909090909 L37.84284215753647 306.4090909090909 L38.24997332652556 306.4090909090909 L38.65710449551466 306.4090909090909 L39.064235664503755 306.4090909090909 L39.47136683349285 306.4090909090909 L39.87849800248195 306.4090909090909 L40.285629171471044 306.4090909090909 L40.69276034046014 306.4090909090909 L41.099891509449236 306.4090909090909 L41.50702267843833 306.4090909090909 L41.91415384742743 306.4090909090909 L42.321285016416525 306.4090909090909 L42.72841618540562 306.4090909090909 L43.13554735439472 306.4090909090909 L43.54267852338381 306.40909090

# %%
x_range = np.arange(10,5000,10)
x_pdf = (1/(x_range*np.sqrt(2*np.pi*sig2)))*np.exp(-(np.log(x_range)-mu)**2/(2*sig2))
x_pdf_plot = {'income': x_range,
        'x_pdf': x_pdf}
x_pdf_plot = pd.DataFrame(x_pdf_plot)

# %%
p5 = (ggplot(x_pdf_plot, aes(x = 'income', y = 'x_pdf')) + 
      geom_line() + 
      labs(title = "income, ML estimate logN"))
p5
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pAu2NES .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pAu2NES .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pAu2NES .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pAu2NES .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pAu2NES .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pAu2NES .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pAu2NES .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pAu2NES .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dJWwk00 .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pAu2NES .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pAu2NES .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dJWwk00 .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pAu2NES .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pAu2NES .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dJWwk00 .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dJWwk00 .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dJWwk00 .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pAu2NES">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="22.382733168452365" y1="0.0" x2="22.382733168452365" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="116.03433638373423" y1="0.0" x2="116.03433638373423" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="209.6859395990161" y1="0.0" x2="209.6859395990161" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="303.33754281429793" y1="0.0" x2="303.33754281429793" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="396.98914602957984" y1="0.0" x2="396.98914602957984" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="490.6407492448617" y1="0.0" x2="490.6407492448617" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="306.40911779073133" x2="513.023482413314" y2="306.40911779073133" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="267.157170316578" x2="513.023482413314" y2="267.157170316578" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="227.90522284242473" x2="513.023482413314" y2="227.90522284242473" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="188.65327536827144" x2="513.023482413314" y2="188.65327536827144" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="149.40132789411814" x2="513.023482413314" y2="149.40132789411814" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="110.14938041996487" x2="513.023482413314" y2="110.14938041996487" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="70.89743294581154" x2="513.023482413314" y2="70.89743294581154" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="31.64548547165822" x2="513.023482413314" y2="31.64548547165822" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cC3jMtJ)" clip-bounds-jfx="[rect (50.97651758668602, 0.0), (513.023482413314, 321.0)]">
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M23.319249200605185 306.40909090909093 L23.319249200605185 306.40909090909093 L24.255765232758 306.4011552318595 L25.19228126491082 306.28326074637255 L26.128797297063638 305.71744249982856 L27.06531332921646 304.16671868883026 L28.001829361369275 301.07466409037534 L28.938345393522095 296.02054779979926 L29.874861425674915 288.78917140927035 L30.81137745782773 279.37068143401865 L31.74789348998055 267.92257383792696 L32.68440952213337 254.7191197980275 L33.62092555428619 240.10277299209253 L34.557441586439005 224.44406930906823 L35.49395761859182 208.11173623898088 L36.430473650744645 191.45232095073638 L37.36698968289746 174.77768165811165 L38.30350571505028 158.35849262820727 L39.2400217472031 142.42207785341947 L40.17653777935592 127.1531848331692 L41.113053811508735 112.69662378650673 L42.04956984366156 99.16097833139486 L42.986085875814375 86.62282414001797 L43.92260190796719 75.13107148877785 L44.859117940120015 64.7111820479314 L45.79563397227283 55.36910790459714 L46.73215000442565 47.09486975881873 L47.66866603657847 39.865738498134476 L48.60518206873128 33.64901565830456 L49.541698100884105 28.40442808140392 L50.47821413303693 24.08616377566915 L51.41473016518974 20.64458207986229 L52.35124619734256 18.02763357282413 L53.28776222949538 16.182025062170112 L54.224278261648195 15.054163363818134 L55.16079429380102 14.590909090909065 L56.09731032595384 14.740168745309802 L57.03382635810665 15.451350338183829 L57.970342390259475 16.675704744552377 L58.906858422412284 18.366572134015655 L59.84337445456511 20.479550179337593 L60.77989048671793 22.972598356290064 L61.71640651887074 25.806090519621478 L62.652922551023565 28.942826064896394 L63.58943858317639 32.34800834947549 L64.5259546153292 35.98919762868593 L65.46247064748202 39.83624454394243 L66.39898667963485 43.86120915650622 L67.3355027117

# %%
import bisect
binno = 50  # number of bins
lx_hist = np.histogram(fes_data_sel['lincome'], bins=binno, density=True)
lx_hist_bp = lx_hist[1][1:-1]  # remove first and last 
lx_hist_den = lx_hist[0]
temp2 = [bisect.bisect_left(lx_hist_bp, x) for x in lx_pdf_plot['lincome']] # identifies the right bin for each value in `lx`.
lx_pdf_plot['hist'] = lx_hist_den[temp2]    # now finds the right bin height

# %%
p6 = (ggplot(lx_pdf_plot) + 
        geom_line(aes(x = 'lincome', y = 'lx_pdf')) +
        geom_area(aes(x = 'lincome', y = 'hist'), color = "red", fill = "orange", alpha = 0.2) +
        labs(title = "Distribution, income", x = "log(income)", y = "Density"))
p6
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pI9NESC .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pI9NESC .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI9NESC .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI9NESC .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pI9NESC .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI9NESC .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI9NESC .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI9NESC .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dXc7ZiC .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI9NESC .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI9NESC .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dXc7ZiC .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI9NESC .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI9NESC .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dXc7ZiC .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dXc7ZiC .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dXc7ZiC .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pI9NESC">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <line x1="24.407513580896307" y1="0.0" x2="24.407513580896307" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="105.83374737871542" y1="0.0" x2="105.83374737871542" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="187.25998117653452" y1="0.0" x2="187.25998117653452" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="268.6862149743536" y1="0.0" x2="268.6862149743536" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="350.11244877217274" y1="0.0" x2="350.11244877217274" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="431.53868256999186" y1="0.0" x2="431.53868256999186" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="512.9649163678109" y1="0.0" x2="512.9649163678109" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="321.0" x2="536.9652987797186" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="282.8174408959558" x2="536.9652987797186" y2="282.8174408959558" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="244.6348817919116" x2="536.9652987797186" y2="244.6348817919116" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="206.45232268786742" x2="536.9652987797186" y2="206.45232268786742" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="168.26976358382322" x2="536.9652987797186" y2="168.26976358382322" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="130.08720447977905" x2="536.9652987797186" y2="130.08720447977905" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="91.90464537573487" x2="536.9652987797186" y2="91.90464537573487" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="53.72208627169067" x2="536.9652987797186" y2="53.72208627169067" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="15.539527167646497" x2="536.9652987797186" y2="15.539527167646497" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cz4i5IO)" clip-bounds-jfx="[rect (27.034701220281416, 0.0), (536.9652987797186, 321.0)]">
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M24.407513580896307 321.0 L24.407513580896307 321.0 L24.814644749885403 321.0 L25.2217759188745 321.0 L25.628907087863595 321.0 L26.03603825685269 321.0 L26.443169425841788 321.0 L26.850300594830884 321.0 L27.25743176381998 321.0 L27.664562932809076 321.0 L28.071694101798172 321.0 L28.47882527078727 321.0 L28.885956439776365 321.0 L29.29308760876546 321.0 L29.700218777754557 321.0 L30.107349946743653 321.0 L30.51448111573275 321.0 L30.921612284721846 321.0 L31.328743453710942 321.0 L31.735874622700038 321.0 L32.143005791689134 321.0 L32.55013696067823 321.0 L32.95726812966733 321.0 L33.36439929865642 321.0 L33.77153046764552 321.0 L34.178661636634615 321.0 L34.58579280562371 321.0 L34.99292397461279 321.0 L35.40005514360189 321.0 L35.807186312590986 321.0 L36.21431748158008 321.0 L36.62144865056918 321.0 L37.028579819558274 321.0 L37.43571098854737 321.0 L37.84284215753647 321.0 L38.24997332652556 321.0 L38.65710449551466 321.0 L39.064235664503755 321.0 L39.47136683349285 321.0 L39.87849800248195 321.0 L40.285629171471044 321.0 L40.69276034046014 321.0 L41.099891509449236 321.0 L41.50702267843833 321.0 L41.91415384742743 321.0 L42.321285016416525 321.0 L42.72841618540562 321.0 L43.13554735439472 321.0 L43.54267852338381 321.0 L43.94980969237291 321.0 L44.356940861362006 321.0 L44.7640720303511 321.0 L45.1712031993402 321.0 L45.578334368329294 321.0 L45.98546553731839 321.0 L46.392596706307486 321.0 L46.79972787529658 321.0 L47.20685904428

# %%
binno = 100  # number of bins
x_hist = np.histogram(fes_data_sel['income'], bins=binno, density=True)
x_hist_bp = x_hist[1][1:-1]  # remove first and last 
x_hist_den = x_hist[0]
temp2 = [bisect.bisect_left(x_hist_bp, x) for x in x_pdf_plot['income']] # identifies the right bin for each value in `lx`.
x_pdf_plot['hist'] = x_hist_den[temp2]    # now finds the right bin height

# %%
p7 = (ggplot(x_pdf_plot) + 
        geom_line(aes(x = 'income', y = 'x_pdf'), color = "black") +
        geom_area(aes(x = 'income', y = 'hist'), color = "red", fill = "orange", alpha = 0.2) +
        labs(title = "Distribution, income", x = "income", y = "Density"))
p7
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pu2Gusi .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pu2Gusi .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pu2Gusi .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pu2Gusi .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pu2Gusi .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pu2Gusi .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pu2Gusi .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pu2Gusi .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dohz2uc .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pu2Gusi .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pu2Gusi .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dohz2uc .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pu2Gusi .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pu2Gusi .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dohz2uc .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dohz2uc .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dohz2uc .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pu2Gusi">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="22.382733168452365" y1="0.0" x2="22.382733168452365" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="116.03433638373423" y1="0.0" x2="116.03433638373423" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="209.6859395990161" y1="0.0" x2="209.6859395990161" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="303.33754281429793" y1="0.0" x2="303.33754281429793" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="396.98914602957984" y1="0.0" x2="396.98914602957984" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="490.6407492448617" y1="0.0" x2="490.6407492448617" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="321.0" x2="513.023482413314" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="279.87891595791723" x2="513.023482413314" y2="279.87891595791723" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="238.7578319158345" x2="513.023482413314" y2="238.7578319158345" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="197.63674787375172" x2="513.023482413314" y2="197.63674787375172" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="156.51566383166897" x2="513.023482413314" y2="156.51566383166897" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="115.3945797895862" x2="513.023482413314" y2="115.3945797895862" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="74.27349574750343" x2="513.023482413314" y2="74.27349574750343" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="33.15241170542066" x2="513.023482413314" y2="33.15241170542066" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cQf2b4S)" clip-bounds-jfx="[rect (50.97651758668602, 0.0), (513.023482413314, 321.0)]">
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M23.319249200605185 320.99997183828407 L23.319249200605185 320.99997183828407 L24.255765232758 320.9916582724265 L25.19228126491082 320.86814977519845 L26.128797297063638 320.2753878572325 L27.06531332921646 318.6508202048858 L28.001829361369275 315.411525209663 L28.938345393522095 310.11673720251787 L29.874861425674915 302.5410102531562 L30.81137745782773 292.67402166419845 L31.74789348998055 280.68076719213235 L32.68440952213337 266.84857851976136 L33.62092555428619 251.53621660979871 L34.557441586439005 235.1318618815725 L35.49395761859182 218.02180024143127 L36.430473650744645 200.56908107097593 L37.36698968289746 183.10041294502003 L38.30350571505028 165.8993593553572 L39.2400217472031 149.20406922446483 L40.17653777935592 133.20808753390727 L41.113053811508735 118.06312021347676 L42.04956984366156 103.88292151913166 L42.986085875814375 90.7477135762467 L43.92260190796719 78.70873571728467 L44.859117940120015 67.79266207053371 L45.79563397227283 58.005728155257884 L46.73215000442565 49.33747946770404 L47.66866603657847 41.764104558915335 L48.60518206873128 35.251347898081804 L49.541698100884105 29.757018561739812 L50.47821413303693 25.233123039129794 L51.41473016518974 21.62765683279298 L52.35124619734256 18.886091982728374 L53.28776222949538 16.95259753062868 L54.224278261648195 15.771028241198678 L55.16079429380102 15.285714285714278 L56.09731032595384 15.442081528301287 L57.03382635810665 16.187128842680067 L57.970342390259475 17.469785721672622 L58.906858422412284 19.241170442696216 L59.84337445456511 21.454766286264828 L60.77989048671793 24.066530802482248 L61.71640651887074 27.034950890623293 L62.652922551023565 30.321054492488486 L63.58943858317639 33.88838798581372 L64.5259546153292 37.70296687931028 L65.46247064748202 41.73320613356043 L66.39898667963485 45.94983533924841 L67.33550271178765 50.325803054112555 L6

# %%
from sklearn.neighbors import KernelDensity

# instantiate and fit the KDE model
kde = KernelDensity(bandwidth=1.0, kernel='gaussian')
# feed in the observed data, requires 2D object which you can get from dataframe using dataframe[['VarName']]
kde.fit(fes_data_sel[['income']]) 

# score_samples returns the log of the probability density for all values of x
temp = kde.score_samples(x_pdf_plot[['income']])
# temp contains the log-likelihood and we need to calculate np.exp(temp) to to get the density
x_pdf_plot['x_pdf_kde_normal_bw1'] = np.exp(temp)

# %%
p8 = (ggplot(x_pdf_plot) + 
        geom_line(aes(x = 'income', y = 'x_pdf'), color = "black") +
        geom_line(aes(x = 'income', y = 'x_pdf_kde_normal_bw1'), color = "cyan") +
        geom_area(aes(x = 'income', y = 'hist'), color = "red", fill = "orange", alpha = 0.2) +
        labs(title = "Distribution, income", x = "income", y = "Density"))
p8
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pgcBUx9 .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pgcBUx9 .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pgcBUx9 .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pgcBUx9 .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pgcBUx9 .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pgcBUx9 .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pgcBUx9 .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pgcBUx9 .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #djRuCTu .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pgcBUx9 .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pgcBUx9 .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #djRuCTu .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pgcBUx9 .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pgcBUx9 .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #djRuCTu .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #djRuCTu .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #djRuCTu .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pgcBUx9">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="22.382733168452365" y1="0.0" x2="22.382733168452365" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="116.03433638373423" y1="0.0" x2="116.03433638373423" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="209.6859395990161" y1="0.0" x2="209.6859395990161" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="303.33754281429793" y1="0.0" x2="303.33754281429793" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="396.98914602957984" y1="0.0" x2="396.98914602957984" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="490.6407492448617" y1="0.0" x2="490.6407492448617" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="321.0" x2="513.023482413314" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="284.3762251389381" x2="513.023482413314" y2="284.3762251389381" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="247.75245027787616" x2="513.023482413314" y2="247.75245027787616" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="211.12867541681425" x2="513.023482413314" y2="211.12867541681425" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="174.50490055575236" x2="513.023482413314" y2="174.50490055575236" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="137.88112569469044" x2="513.023482413314" y2="137.88112569469044" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="101.25735083362852" x2="513.023482413314" y2="101.25735083362852" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="64.63357597256658" x2="513.023482413314" y2="64.63357597256658" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="28.009801111504657" x2="513.023482413314" y2="28.009801111504657" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cXTprzV)" clip-bounds-jfx="[rect (50.97651758668602, 0.0), (513.023482413314, 321.0)]">
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M23.319249200605185 320.99997491825985 L23.319249200605185 320.99997491825985 L24.255765232758 320.9925705861185 L25.19228126491082 320.88256990152377 L26.128797297063638 320.3546368585237 L27.06531332921646 318.9077440702592 L28.001829361369275 316.0227225933887 L28.938345393522095 311.3070121876931 L29.874861425674915 304.5598233752979 L30.81137745782773 295.7719624261839 L31.74789348998055 285.090379927365 L32.68440952213337 272.77098282065907 L33.62092555428619 259.1332952877219 L34.557441586439005 244.52304343510264 L35.49395761859182 229.2842660544739 L36.430473650744645 213.74030673282851 L37.36698968289746 198.18214275269398 L38.30350571505028 182.86232498241895 L39.2400217472031 167.9929565978655 L40.17653777935592 153.74641505442966 L41.113053811508735 140.257814587235 L42.04956984366156 127.62846843635674 L42.986085875814375 115.92982503578057 L43.92260190796719 105.20751980149464 L44.859117940120015 95.48530957969601 L45.79563397227283 86.76874792664387 L46.73215000442565 79.04852372127567 L47.66866603657847 72.30342971271207 L48.60518206873128 66.50295681109426 L49.541698100884105 61.60952840777719 L50.47821413303693 57.58039992114783 L51.41473016518974 54.369254454386464 L52.35124619734256 51.9275276328608 L53.28776222949538 50.2054945892682 L54.224278261648195 49.15315055099961 L55.16079429380102 48.7209141579998 L56.09731032595384 48.860179909901944 L57.03382635810665 49.52374327984427 L57.970342390259475 50.66611921312807 L58.906858422412284 52.24377205780263 L59.84337445456511 54.21527251059405 L60.77989048671793 56.54139493319764 L61.71640651887074 59.18516640794462 L62.652922551023565 62.11187715228374 L63.589

# %%
kde = KernelDensity(bandwidth=100.0, kernel='gaussian')
# noe feed in the observed data, requires 2D object which you can get fram dataframe using dataframe[['VarName']]
kde.fit(fes_data_sel[['income']]) 

# score_samples returns the log of the probability density for all values of x
temp = kde.score_samples(x_pdf_plot[['income']])
# temp contains the log-likelihood and we need to calculate np.exp(temp) to to get the density
x_pdf_plot['x_pdf_kde_normal_bw100'] = np.exp(temp)

# %%
p9 = (ggplot(x_pdf_plot) + 
        geom_line(aes(x = 'income', y = 'x_pdf'), color = "black") +
        geom_line(aes(x = 'income', y = 'x_pdf_kde_normal_bw1'), color = "cyan") +
        geom_line(aes(x = 'income', y = 'x_pdf_kde_normal_bw100'), color = "blue") +
        geom_area(aes(x = 'income', y = 'hist'), color = "red", fill = "orange", alpha = 0.2) +
        labs(title = "Distribution, income", x = "income", y = "Density"))
p9
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pf6KIp6 .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pf6KIp6 .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pf6KIp6 .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pf6KIp6 .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pf6KIp6 .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pf6KIp6 .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pf6KIp6 .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pf6KIp6 .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dJDULvH .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pf6KIp6 .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pf6KIp6 .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dJDULvH .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pf6KIp6 .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pf6KIp6 .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dJDULvH .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dJDULvH .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dJDULvH .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pf6KIp6">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="22.382733168452365" y1="0.0" x2="22.382733168452365" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="116.03433638373423" y1="0.0" x2="116.03433638373423" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="209.6859395990161" y1="0.0" x2="209.6859395990161" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="303.33754281429793" y1="0.0" x2="303.33754281429793" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="396.98914602957984" y1="0.0" x2="396.98914602957984" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="490.6407492448617" y1="0.0" x2="490.6407492448617" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="321.0" x2="513.023482413314" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="284.3762251389381" x2="513.023482413314" y2="284.3762251389381" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="247.75245027787616" x2="513.023482413314" y2="247.75245027787616" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="211.12867541681425" x2="513.023482413314" y2="211.12867541681425" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="174.50490055575236" x2="513.023482413314" y2="174.50490055575236" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="137.88112569469044" x2="513.023482413314" y2="137.88112569469044" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="101.25735083362852" x2="513.023482413314" y2="101.25735083362852" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="64.63357597256658" x2="513.023482413314" y2="64.63357597256658" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="28.009801111504657" x2="513.023482413314" y2="28.009801111504657" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cubqgtO)" clip-bounds-jfx="[rect (50.97651758668602, 0.0), (513.023482413314, 321.0)]">
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M23.319249200605185 320.99997491825985 L23.319249200605185 320.99997491825985 L24.255765232758 320.9925705861185 L25.19228126491082 320.88256990152377 L26.128797297063638 320.3546368585237 L27.06531332921646 318.9077440702592 L28.001829361369275 316.0227225933887 L28.938345393522095 311.3070121876931 L29.874861425674915 304.5598233752979 L30.81137745782773 295.7719624261839 L31.74789348998055 285.090379927365 L32.68440952213337 272.77098282065907 L33.62092555428619 259.1332952877219 L34.557441586439005 244.52304343510264 L35.49395761859182 229.2842660544739 L36.430473650744645 213.74030673282851 L37.36698968289746 198.18214275269398 L38.30350571505028 182.86232498241895 L39.2400217472031 167.9929565978655 L40.17653777935592 153.74641505442966 L41.113053811508735 140.257814587235 L42.04956984366156 127.62846843635674 L42.986085875814375 115.92982503578057 L43.92260190796719 105.20751980149464 L44.859117940120015 95.48530957969601 L45.79563397227283 86.76874792664387 L46.73215000442565 79.04852372127567 L47.66866603657847 72.30342971271207 L48.60518206873128 66.50295681109426 L49.541698100884105 61.60952840777719 L50.47821413303693 57.58039992114783 L51.41473016518974 54.369254454386464 L52.35124619734256 51.9275276328608 L53.28776222949538 50.2054945892682 L54.224278261648195 49.15315055099961 L55.16079429380102 48.7209141579998 L56.09731032595384 48.860179909901944 L57.03382635810665 49.52374327984427 L57.970342390259475 50.66611921312807 L58.906858422412284 52.24377205780263 L59.84337445456511 54.21527251059405 L60.77989048671793 56.54139493319764 L61.71640651887074 59.18516640794462 L62.652922551023565 62.11187715228374 L63.589

# %%
sigmahat = np.std(fes_data_sel['income'])
n = len(fes_data_sel['income']) - sum(fes_data_sel['income'].isna()) # checking for missing observations
hopt = 1.06 * sigmahat * n **(-0.2)

print("Optimal bandwidth (Silverman), income = ", round(hopt,4))
# Out:
# Optimal bandwidth (Silverman), income =  63.4507

# %%
kde = KernelDensity(bandwidth=hopt, kernel='gaussian')
kde.fit(fes_data_sel[['income']]) 
temp = kde.score_samples(x_pdf_plot[['income']])
x_pdf_plot['x_pdf_kde_normal_bwopt'] = np.exp(temp)

# %%
p10 = (ggplot(x_pdf_plot) + 
        geom_line(aes(x = 'income', y = 'x_pdf_kde_normal_bw1'), color = "cyan") +
        geom_line(aes(x = 'income', y = 'x_pdf_kde_normal_bw100'), color = "blue") +
        geom_line(aes(x = 'income', y = 'x_pdf_kde_normal_bwopt'), color = "red") +
        labs(title = "Distribution, income", x = "income", y = "Density"))
p10
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pM7bOKr .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pM7bOKr .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pM7bOKr .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pM7bOKr .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pM7bOKr .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pM7bOKr .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pM7bOKr .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pM7bOKr .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dxbM4sF .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pM7bOKr .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pM7bOKr .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dxbM4sF .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pM7bOKr .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pM7bOKr .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dxbM4sF .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dxbM4sF .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dxbM4sF .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pM7bOKr">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="22.382733168452365" y1="0.0" x2="22.382733168452365" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="116.03433638373423" y1="0.0" x2="116.03433638373423" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="209.6859395990161" y1="0.0" x2="209.6859395990161" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="303.33754281429793" y1="0.0" x2="303.33754281429793" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="396.98914602957984" y1="0.0" x2="396.98914602957984" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="490.6407492448617" y1="0.0" x2="490.6407492448617" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="306.4090909090909" x2="513.023482413314" y2="306.4090909090909" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="271.45003308716815" x2="513.023482413314" y2="271.45003308716815" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="236.4909752652454" x2="513.023482413314" y2="236.4909752652454" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="201.53191744332264" x2="513.023482413314" y2="201.53191744332264" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="166.5728596213999" x2="513.023482413314" y2="166.5728596213999" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="131.6138017994772" x2="513.023482413314" y2="131.6138017994772" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="96.65474397755443" x2="513.023482413314" y2="96.65474397755443" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="61.69568615563168" x2="513.023482413314" y2="61.69568615563168" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="26.73662833370895" x2="513.023482413314" y2="26.73662833370895" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cleB0xt)" clip-bounds-jfx="[rect (50.97651758668602, 0.0), (513.023482413314, 321.0)]">
#         <g transform="translate(50.97651758668602 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M23.319249200605185 297.1822640359635 L23.319249200605185 297.1822640359635 L24.255765232758 303.50675399591717 L25.19228126491082 297.6230369563225 L26.128797297063638 302.8342759905587 L27.06531332921646 289.8375800661192 L28.001829361369275 286.8051908117767 L28.938345393522095 281.921309830439 L29.874861425674915 269.4558833141552 L30.81137745782773 239.99651154790712 L31.74789348998055 259.2640859201064 L32.68440952213337 244.76250242674786 L33.62092555428619 175.7970206874242 L34.557441586439005 186.8951388785286 L35.49395761859182 218.43573690330237 L36.430473650744645 218.28074644545978 L37.36698968289746 208.1861785055649 L38.30350571505028 212.2793867918399 L39.2400217472031 187.9666222322917 L40.17653777935592 178.35709530331647 L41.113053811508735 178.00578668217568 L42.04956984366156 145.73983408701866 L42.986085875814375 161.2292606534404 L43.92260190796719 168.66510872903953 L44.859117940120015 184.65831044740673 L45.79563397227283 170.94290316833218 L46.73215000442565 121.34981277985568 L47.66866603657847 169.03022477058548 L48.60518206873128 159.88783833702624 L49.541698100884105 138.0322835463253 L50.47821413303693 98.74411319472134 L51.41473016518974 138.88237556412116 L52.35124619734256 69.78614030207646 L53.28776222949538 121.46162800423886 L54.224278261648195 106.38228140578386 L55.16079429380102 98.07981713717285 L56.09731032595384 79.76448965781657 L57.03382635810665 85.50468146585149 L57.970342390259475 88.59778254056619 L58.906858422412284 73.68105357864096 L59.84337445456511 29.951932445185946 L60.77989048671793 55.86236847658003 L61.71640651887074 62.570986633826124 L62.652922551023565

# %%
sigmahat = np.std(fes_data_sel['lincome'])
n = len(fes_data_sel['lincome']) - sum(fes_data_sel['lincome'].isna()) # checking for missing observations
hopt = 1.06 * sigmahat * n **(-0.2)

print("Optimal bandwidth (Silverman), log(income) = ", round(hopt,4))

kde = KernelDensity(bandwidth=hopt, kernel='gaussian')
kde.fit(fes_data_sel[['lincome']]) 
temp = kde.score_samples(lx_pdf_plot[['lincome']])
lx_pdf_plot['lx_pdf_kde_normal_bwopt'] = np.exp(temp) 

p11 = (ggplot(lx_pdf_plot) + 
        geom_line(aes(x = 'lincome', y = 'lx_pdf'), color = "red") +
        geom_line(aes(x = 'lincome', y = 'lx_pdf_kde_normal_bwopt'), color = "blue") +
        geom_area(aes(x = 'lincome', y = 'hist'), color = "orange", fill = "orange", alpha = 0.2) +

        labs(title = "Distribution, income", x = "ln(income)", y = "Density"))
p11
# Out:
# Optimal bandwidth (Silverman), log(income) =  0.0876
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pzvRWjT .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pzvRWjT .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pzvRWjT .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pzvRWjT .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pzvRWjT .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pzvRWjT .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pzvRWjT .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pzvRWjT .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dpn124X .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pzvRWjT .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pzvRWjT .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dpn124X .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pzvRWjT .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pzvRWjT .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dpn124X .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dpn124X .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dpn124X .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pzvRWjT">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <line x1="24.407513580896307" y1="0.0" x2="24.407513580896307" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="105.83374737871542" y1="0.0" x2="105.83374737871542" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="187.25998117653452" y1="0.0" x2="187.25998117653452" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="268.6862149743536" y1="0.0" x2="268.6862149743536" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="350.11244877217274" y1="0.0" x2="350.11244877217274" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="431.53868256999186" y1="0.0" x2="431.53868256999186" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="512.9649163678109" y1="0.0" x2="512.9649163678109" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="321.0" x2="536.9652987797186" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="282.8174408959558" x2="536.9652987797186" y2="282.8174408959558" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="244.6348817919116" x2="536.9652987797186" y2="244.6348817919116" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="206.45232268786742" x2="536.9652987797186" y2="206.45232268786742" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="168.26976358382322" x2="536.9652987797186" y2="168.26976358382322" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="130.08720447977905" x2="536.9652987797186" y2="130.08720447977905" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="91.90464537573487" x2="536.9652987797186" y2="91.90464537573487" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="53.72208627169067" x2="536.9652987797186" y2="53.72208627169067" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="15.539527167646497" x2="536.9652987797186" y2="15.539527167646497" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cNtyTqZ)" clip-bounds-jfx="[rect (27.034701220281416, 0.0), (536.9652987797186, 321.0)]">
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M24.407513580896307 321.0 L24.407513580896307 321.0 L24.814644749885403 321.0 L25.2217759188745 321.0 L25.628907087863595 321.0 L26.03603825685269 321.0 L26.443169425841788 321.0 L26.850300594830884 321.0 L27.25743176381998 321.0 L27.664562932809076 321.0 L28.071694101798172 321.0 L28.47882527078727 321.0 L28.885956439776365 321.0 L29.29308760876546 321.0 L29.700218777754557 321.0 L30.107349946743653 321.0 L30.51448111573275 321.0 L30.921612284721846 321.0 L31.328743453710942 321.0 L31.735874622700038 321.0 L32.143005791689134 321.0 L32.55013696067823 321.0 L32.95726812966733 321.0 L33.36439929865642 321.0 L33.77153046764552 321.0 L34.178661636634615 321.0 L34.58579280562371 321.0 L34.99292397461279 321.0 L35.40005514360189 321.0 L35.807186312590986 321.0 L36.21431748158008 321.0 L36.62144865056918 321.0 L37.028579819558274 321.0 L37.43571098854737 321.0 L37.84284215753647 321.0 L38.24997332652556 321.0 L38.65710449551466 321.0 L39.064235664503755 321.0 L39.47136683349285 321.0 L39.87849800248195 321.0 L40.285629171471044 321.0 L40.69276034046014 321.0 L41.099891509449236 321.0 L41.50702267843833 321.0 L41.91415384742743 321.0 L42.321285016416525 321.0 L42.72841618540562 321.0 L43.13554735439472 321.0 L43.54267852338381 321.0 L43.94980969237291 321.0 L44.356940861362006 321.0 L44.7640720303511 321.0 L45.1712031993402 321.0 L45.578334368329294 321.0 L45.98546553731839 321.0 L46.392596706307486 321.0 L46.79972787529658 321.0 L47.20685904428

# %%
sigmahat = np.std(fes_data_sel['lincome'])
iqr = np.percentile(fes_data_sel['lincome'],75)-np.percentile(fes_data_sel['lincome'],25)

n = len(fes_data_sel['lincome']) - sum(fes_data_sel['lincome'].isna()) # checking for missing observations
hopt = 1.06 * np.min([sigmahat,iqr/1.34]) * n **(-0.2)

print("Plug-in bandwidth (Ebanechnikov), log(income) = ", round(hopt,4))

kde = KernelDensity(bandwidth=hopt, kernel='epanechnikov')
kde.fit(fes_data_sel[['lincome']]) 
temp = kde.score_samples(lx_pdf_plot[['lincome']])
lx_pdf_plot['lx_pdf_kde_epa_bwopt'] = np.exp(temp) 

p11 = (ggplot(lx_pdf_plot) + 
        geom_line(aes(x = 'lincome', y = 'lx_pdf_kde_epa_bwopt'), color = "red") +
        geom_line(aes(x = 'lincome', y = 'lx_pdf_kde_normal_bwopt'), color = "blue") +
        geom_area(aes(x = 'lincome', y = 'hist'), color = "orange", fill = "orange", alpha = 0.2) +
        xlim(3,9) +
        labs(title = "Distribution, income", x = "ln(income)", y = "Density"))
p11
# Out:
# Plug-in bandwidth (Ebanechnikov), log(income) =  0.0732
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #ph2gbcr .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #ph2gbcr .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #ph2gbcr .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #ph2gbcr .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #ph2gbcr .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #ph2gbcr .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #ph2gbcr .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #ph2gbcr .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #d8ljEFP .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #ph2gbcr .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #ph2gbcr .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #d8ljEFP .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #ph2gbcr .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #ph2gbcr .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #d8ljEFP .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #d8ljEFP .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #d8ljEFP .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="ph2gbcr">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <line x1="24.40751358089628" y1="0.0" x2="24.40751358089628" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="105.76589218388395" y1="0.0" x2="105.76589218388395" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="187.12427078687162" y1="0.0" x2="187.12427078687162" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="268.48264938985926" y1="0.0" x2="268.48264938985926" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="349.841027992847" y1="0.0" x2="349.841027992847" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="431.1994065958346" y1="0.0" x2="431.1994065958346" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="512.5577851988222" y1="0.0" x2="512.5577851988222" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="321.0" x2="536.9652987797186" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="283.9503856761632" x2="536.9652987797186" y2="283.9503856761632" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="246.90077135232636" x2="536.9652987797186" y2="246.90077135232636" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="209.85115702848952" x2="536.9652987797186" y2="209.85115702848952" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="172.80154270465272" x2="536.9652987797186" y2="172.80154270465272" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="135.7519283808159" x2="536.9652987797186" y2="135.7519283808159" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="98.7023140569791" x2="536.9652987797186" y2="98.7023140569791" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="61.6526997331423" x2="536.9652987797186" y2="61.6526997331423" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="24.603085409305493" x2="536.9652987797186" y2="24.603085409305493" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cJZ2q0M)" clip-bounds-jfx="[rect (27.034701220281416, 0.0), (536.9652987797186, 321.0)]">
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M24.407513580896648 320.8538571164376 L24.407513580896648 320.8538571164376 L25.2210973669265 320.8484151911525 L26.034681152956438 320.8486502336077 L26.84826493898629 320.82630621395606 L27.661848725016142 320.80322307850105 L28.475432511046023 320.79149387852664 L29.289016297075875 320.7911186140327 L30.102600083105813 320.8020972850194 L30.916183869135665 320.8244298914866 L31.729767655165517 320.8488658059127 L32.543351441195455 320.8482554989636 L33.35693522722531 320.85332215975484 L34.17051901325516 320.8640657882863 L34.98410279928504 320.85954120210573 L35.79768658531489 320.8458760609325 L36.61127037134483 320.8435648552398 L37.424854157374654 320.8526075850276 L38.238437943404534 320.8625482294217 L39.05202172943447 320.81180401213027 L39.86560551546435 320.7724137303194 L40.679189301494176 320.74437738398905 L41.49277308752406 320.72769497313925 L42.30635687355388 320.72236649777005 L43.11994065958382 320.7283919578814 L43.9335244456137 320.7457713534733 L44.74710823164358 320.7745046845457 L45.56069201767352 320.7908015138844 L46.37427580370334 320.8069007472305 L47.18785958973322 320.80047010180397 L48.001443375763046 320.76262854804787 L48.815027161792926 320.7418178975126 L49.628610947822864 320.7036409236406 L50.442194733852745 320.65993790963626 L51.25577851988257 320.6147009264505 L52.069362305912506 320.5492163487365 L52.88294609194239 320.4783496132093 L53.69652987797221 320.4216511296215 L54.51011366400209 320.3933374847352 L

# %%
bw_sel = np.linspace(0.05, 0.40, 20)
bw_sel
# Out:
# array([0.05      , 0.06842105, 0.08684211, 0.10526316, 0.12368421,
#        0.14210526, 0.16052632, 0.17894737, 0.19736842, 0.21578947,
#        0.23421053, 0.25263158, 0.27105263, 0.28947368, 0.30789474,
#        0.32631579, 0.34473684, 0.36315789, 0.38157895, 0.4       ])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

# This procedure can take a lot of time
# for testing we take a random sample of 1000, fes_data_sel[['lincome']].sample(1000)
# if you wish to run on all data delete `.sample(1000)`
# WARNING: will take a few minutes

kde = KernelDensity(kernel='gaussian')
grid = GridSearchCV(kde, {'bandwidth': bw_sel}, cv = 3)
grid.fit(fes_data_sel[['lincome']].sample(1000))
# Out:
# GridSearchCV(cv=3, estimator=KernelDensity(),
#              param_grid={'bandwidth': array([0.05      , 0.06842105, 0.08684211, 0.10526316, 0.12368421,
#        0.14210526, 0.16052632, 0.17894737, 0.19736842, 0.21578947,
#        0.23421053, 0.25263158, 0.27105263, 0.28947368, 0.30789474,
#        0.32631579, 0.34473684, 0.36315789, 0.38157895, 0.4       ])})

# %%
kde_best = grid.best_estimator_
# Print the best bandwidth
print("Best bandwidth: ", round(kde_best.bandwidth,4))
# Out:
# Best bandwidth:  0.2342

# %%
temp = kde_best.score_samples(lx_pdf_plot[['lincome']])
lx_pdf_plot['lx_pdf_kde_normal_bwcv'] = np.exp(temp)

# %%
p12 = (ggplot(lx_pdf_plot) + 
        geom_line(aes(x = 'lincome', y = 'lx_pdf_kde_normal_bwopt'), color = "red") +
        geom_line(aes(x = 'lincome', y = 'lx_pdf_kde_normal_bwcv'), color = "blue") +
        xlim(3,9) +
        labs(title = "Distribution, income", x = "ln(income)", y = "Density"))
p12
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pbeBr4Y .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pbeBr4Y .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pbeBr4Y .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pbeBr4Y .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pbeBr4Y .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pbeBr4Y .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pbeBr4Y .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pbeBr4Y .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dbxVRIE .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pbeBr4Y .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pbeBr4Y .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dbxVRIE .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pbeBr4Y .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pbeBr4Y .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dbxVRIE .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dbxVRIE .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dbxVRIE .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pbeBr4Y">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <line x1="24.40751358089628" y1="0.0" x2="24.40751358089628" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="105.76589218388395" y1="0.0" x2="105.76589218388395" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="187.12427078687162" y1="0.0" x2="187.12427078687162" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="268.48264938985926" y1="0.0" x2="268.48264938985926" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="349.841027992847" y1="0.0" x2="349.841027992847" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="431.1994065958346" y1="0.0" x2="431.1994065958346" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="512.5577851988222" y1="0.0" x2="512.5577851988222" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="306.40909090909093" x2="536.9652987797186" y2="306.40909090909093" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="269.7218074800184" x2="536.9652987797186" y2="269.7218074800184" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="233.0345240509459" x2="536.9652987797186" y2="233.0345240509459" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="196.34724062187337" x2="536.9652987797186" y2="196.34724062187337" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="159.65995719280085" x2="536.9652987797186" y2="159.65995719280085" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="122.97267376372832" x2="536.9652987797186" y2="122.97267376372832" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="86.2853903346558" x2="536.9652987797186" y2="86.2853903346558" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="49.59810690558328" x2="536.9652987797186" y2="49.59810690558328" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="12.910823476510757" x2="536.9652987797186" y2="12.910823476510757" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cqsvFNr)" clip-bounds-jfx="[rect (27.034701220281416, 0.0), (536.9652987797186, 321.0)]">
#         <g transform="translate(27.034701220281416 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M24.407513580896648 306.2991032103913 L24.407513580896648 306.2991032103913 L25.2210973669265 306.2916821324435 L26.034681152956438 306.28461332308166 L26.84826493898629 306.2779575819393 L27.661848725016142 306.2717475819552 L28.475432511046023 306.26598739340074 L29.289016297075875 306.2606536248229 L30.102600083105813 306.2556980909583 L30.916183869135665 306.25105177868505 L31.729767655165517 306.24662976104264 L32.543351441195455 306.2423366211858 L33.35693522722531 306.23807190534154 L34.17051901325516 306.2337351347608 L34.98410279928504 306.22922997395887 L35.79768658531489 306.22446727200537 L36.61127037134483 306.2193668536785 L37.424854157374654 306.2138581194303 L38.238437943404534 306.20787969351494 L39.05202172943447 306.20137851188156 L39.86560551546435 306.19430884018067 L40.679189301494176 306.1866317372645 L41.49277308752406 306.17831541971873 L42.30635687355388 306.1693368390885 L43.11994065958382 306.15968456973553 L43.9335244456137 306.1493628484689 L44.74710823164358 306.1383963436644 L45.56069201767352 306.1268350027313 L46.37427580370334 306.1147581723228 L47.18785958973322 306.1022771375844 L48.001443375763046 306.0895353034032 L48.815027161792926 306.0767054429818 L49.628610947822864 306.06398374919024 L50.442194733852745 306.0515808068039 L51.25577851988257 306.03971001066884 L52.069362305912506 306.0285743313246 L52.88294609194239 306.01835262216684 L53.69652987797221 306.0091868264092 L54.510
